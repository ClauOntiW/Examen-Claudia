# %% [markdown]
#  # Examen final Claudia Ontiveros Wade

# %%
# Importar librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Vamos a buscar la base de datos
Mortalidad=pd.read_csv('mortalidad (1).csv')

# %%
# Vamos a imprimir la tabla
pd.DataFrame(Mortalidad)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
#Vamos a imprimir los encabezados
Mortalidad.head(2)
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
#
#   Descripción del estado conyugal  Entidad de residencia  \
# 0                          CASADO                     31
# 1                          CASADO                     31
#
#                          ...                         Mes de registro  \
# 0                        ...                                       1
# 1                        ...                                       7
#
#    Descripción del mes de registro Día de registro  Año de la certificación  \
# ...

# %%
# Vamos a graficar la Edad cumplida

Mortalidad.describe( )
# Out:
#        Año de nacimiento  Mes de nacimiento  Día de nacimiento   Genero  \
# count       17232.000000       17232.000000       17232.000000  17232.0
# mean         1971.559424           3.758008           9.903726      2.0
# std           128.025187           3.756571          10.157461      0.0
# min             0.000000           0.000000           0.000000      2.0
# 25%          1974.000000           0.000000           0.000000      2.0
# 50%          1980.000000           3.000000           7.000000      2.0
# 75%          1986.000000           7.000000          19.000000      2.0
# max          2002.000000          12.000000          31.000000      2.0
#
#        Edad cumplida  Estado conyugal  Entidad de residencia  \
# count   17232.000000     17232.000000           17232.000000
# mean       29.765727         3.918001              16.293350
# std        36.916010         1.454535               7.844138
# min        11.000000         0.000000               0.000000
# ...

# %%
# Para graficar la columna de edad cumplida

EC= Mortalidad['Edad cumplida']

# %%
len(EC)
# Out:
# 17232

# %%
#Con estos datos vamos a observar si la edad influye en la mortalidad materna
# Graficar el histograma de edad
#No pude eliminar los datos de edad que están sobrando por eso me sale la gráfica asi

plt.hist(EC,17232)
plt.xlabel('personas')
plt.ylabel('edad_cumplida')
plt.title('Mortalidad por edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Para el estado conyugal

Conyuge= Mortalidad['Estado conyugal']

# %%
#Con esta grafica vamos a ver si influye el # de conyuges en la mortalidad materna
#Graficar conyuge
plt.hist(Conyuge,1732)
plt.xlabel('personas')
plt.ylabel('Estado conyugal')
plt.title('Mortalidad por estado conyugal')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Tamaño de la localidad 
# Con esta grafica vamos a ver si influye el tamaño de la localidad en la defunción materna

Localidad= Mortalidad['Tamaño de localidad']

# %%
# Con esta grafica vamos a saber si el tamaño de la localidad influye en la mortalidad, ya que es un indicativo si es una poblacion donde no hay servicios o si hay
plt.hist(Localidad,1732)
plt.xlabel('personas')
plt.ylabel('Localidad')
plt.title('Mortalidad por tamaño de la localidad')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Cuantas edades diferentes tenian las madres en el momento de defuncion?


Edades= Mortalidad['Edad cumplida'].unique( )

# %%
print("Las edades de las madres al momento de morir eran de"+str(Edades))
# Out:
# Las edades de las madres al momento de morir eran de[ 29  35  36  30  20  27  43  31  39  45  42  17  38  26  21  22  40  44
#   34  41  33  13  24  25  37  19  23  32  28 998  15  46  48  16  18  12
#   47  14  51  50  54  49  11  53  81  70  82  59  86  65]

# %%
# Valores de años de defuncion
Ano= Mortalidad['Año de registro'].unique ( )

# %%
print("Los años de las defunciones fueron" +str(Ano))
# Out:
# Los años de las defunciones fueron[2002 2005 2003 2008 2013 2012 2009 2010 2011 2004 2006 2007 2014 2015
#  2016]

# %% [raw]
#  # Parte 4  Dataframes

# %%
#  Borrar datos innecesarios
# OCDE2=OCDE.drop(["MEASURE","INEQUALITY","Unit Code", "PowerCode Code", "Reference Period Code", "Reference Period", "Flag Codes", "Flags"],axis=1)
Mortalidad2= Mortalidad.drop(['Año de la certificación', 'Mes de la certificación','Día de la certificación', 'Año de la base de datos', 'Clave de la edad', 'Genero', 'Descrición de la entidad de registro', 'Municipio de registro','Descrición del municipio de registro', 'Entidad de registro', 'Descripció del mes de la certificación', 'Descripción del mes de registro'],axis=1)

# %%
pd.DataFrame(Mortalidad2)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
# Data Frame 1 :  Podemos analizar las causas de la mortalidad materna ver cuales fueron estas y cual fue la que mas se presento en la columna Descrición de la causa CIE

# %%
#Data Frame 2  Podemos analizar las causas de defunción materna con o sin asistencia médica, que tanto influye, en la colunma CON ATENCION MEDICA
